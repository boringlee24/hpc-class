# %%
from sklearn.tree import DecisionTreeClassifier
import sklearn.datasets as datasets
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from time import perf_counter

# %%
df = pd.read_csv('/work/li.baol/data/SUSY.csv', header=None)
df
# Out:
#           0         1         2         3         4         5         6   \
# 0        0.0  0.972861  0.653855  1.176225  1.157156 -1.739873 -0.874309
# 1        1.0  1.667973  0.064191 -1.225171  0.506102 -0.338939  1.672543
# 2        1.0  0.444840 -0.134298 -0.709972  0.451719 -1.613871 -0.768661
# 3        1.0  0.381256 -0.976145  0.693152  0.448959  0.891753 -0.677328
# 4        1.0  1.309996 -0.690089 -0.676259  1.589283 -0.693326  0.622907
# ...      ...       ...       ...       ...       ...       ...       ...
# 4999995  1.0  0.853325 -0.961783 -1.487277  0.678190  0.493580  1.647969
# 4999996  0.0  0.951581  0.139370  1.436884  0.880440 -0.351948 -0.740852
# 4999997  0.0  0.840389  1.419162 -1.218766  1.195631  1.695645  0.663756
# 4999998  1.0  1.784218 -0.833565 -0.560091  0.953342 -0.688969 -1.428233
# 4999999  0.0  0.761500  0.680454 -1.186213  1.043521 -0.316755  0.246879
#
#                7         8         9         10        11        12        13  \
# 0        0.567765 -0.175000  0.810061 -0.252552  1.921887  0.889637  0.410772
# 1        3.475464 -1.219136  0.012955  3.775174  1.045977  0.568051  0.481928
# 2        1.219918  0.504026  1.831248 -0.431385  0.526283  0.941514  1.587535
# 3        2.033060  1.533041  3.046260 -1.005285  0.569386  1.015211  1.582217
# 4        1.087562 -0.381742  0.589204  1.365479  1.179295  0.968218  0.728563
# ...           ...       ...       ...       ...       ...       ...       ...
# 4999995  1.843867  0.276954  1.025105 -1.486535  0.892879  1.684429  1.674084
# 4999996  0.290863 -0.732360  0.001360  0.257738  0.802871  0.545319  0.602730
# 4999997  0.490888 -0.509186  0.704289  0.045744  0.825015  0.723530  0.778236
# 4999998  2.660703 -0.861344  2.116892  2.906151  1.232334  0.952444  0.685846
# 4999999  1.120280  0.998479  1.640881 -0.797688  0.854212  1.121858  1.165438
#
#                14        15        16        17        18
# 0        1.145621  1.932632  0.994464  1.367815  0.040714
# 1        0.000000  0.448410  0.205356  1.321893  0.377584
# 2        2.024308  0.603498  1.562374  1.135454  0.180910
# 3        1.551914  0.761215  1.715464  1.492257  0.090719
# 4        0.000000  1.083158  0.043429  1.154854  0.094859
# ...           ...       ...       ...       ...       ...
# 4999995  3.366298  1.046707  2.646649  1.389226  0.364599
# 4999996  0.002998  0.748959  0.401166  0.443471  0.239953
# 4999997  0.752942  0.838953  0.614048  1.210595  0.026692
# 4999998  0.000000  0.781874  0.676003  1.197807  0.093689
# 4999999  1.498351  0.931580  1.293524  1.539167  0.187496
#
# [5000000 rows x 19 columns]

# %%
df.shape
# Out:
# (5000000, 19)

# %%
y = df[0].to_numpy()
X = df.drop(columns=0).to_numpy()
X, y
# Out:
# (array([[ 0.97286147,  0.65385455,  1.17622459, ...,  0.9944641 ,
#           1.36781549,  0.0407145 ],
#         [ 1.66797304,  0.06419062, -1.22517145, ...,  0.20535576,
#           1.32189345,  0.37758401],
#         [ 0.44483992, -0.13429801, -0.70997161, ...,  1.562374  ,
#           1.13545442,  0.18091001],
#         ...,
#         [ 0.84038883,  1.41916203, -1.21876585, ...,  0.61404794,
#           1.21059453,  0.0266919 ],
#         [ 1.78421772, -0.83356524, -0.56009114, ...,  0.67600298,
#           1.19780684,  0.0936892 ],
#         [ 0.76150006,  0.68045425, -1.18621314, ...,  1.29352391,
#           1.53916669,  0.18749601]]),
#  array([0., 1., 1., ..., 0., 1., 0.]))

# %%
# X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.7, test_size=0.3)

# %%
start = perf_counter()

clf = DecisionTreeClassifier(criterion='gini', splitter='best', max_depth=8, random_state=0)
clf = clf.fit(X, y)
end = perf_counter()
end-start
# Out:
# 159.36909877415746

# %%
X_train.size, X.size
# Out:
# (63000000, 90000000)
